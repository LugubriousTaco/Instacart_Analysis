# %% [markdown]
# # Table of Contents
#     ## Grouping data
#     ## Grouping data with pandas
#     ## Aggregating data with agg()
#     ## Aggregating data with transform()
#     ## Deriving columns with loc()

# %% [markdown]
# # Grouping Data

# %% [markdown]
# ## Set Up Notebook

# %%
#import necessary libraries
import pandas as pd
import numpy as np
import os

# %%
#import necessary datasets
path = r'C:\Users\mmreg\OneDrive\Desktop\Data Analytics Course Work\Data Immersion\Tasks\04-2022 Instacart Basket Analysis'

# %%
ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
#create test subset
df = ords_prods_merged[:1000000]

# %%
#verify df creation
df.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# 0                                     Soda      77.0            7.0     9.0
# 1  Organic Unsweetened Vanilla Almond Milk      91.0           16.0    12.5
# 2                      Original Beef Jerky      23.0           19.0     4.4
# 3               Aged White Cheddar Popcorn      23.0           19.0     4.7
# 4         XL Pick-A-Size Paper Towel Rolls      54.0           17.0     1.0
#
#   _merge    price_range_loc     busiest_day busiest_period_of_day
# 0   both  Mid-Range Product  regularly busy        Average Orders
# 1   both  Mid-Range Product  regularly busy        Average Orders
# 2   both  Low-Range Product  regularly busy        Average Orders
# 3   both  Low-Range Product  regularly busy        Average Orders
# 4   both  Low-Range Product  regularly busy        Average Orders

# %% [markdown]
# # Grouping Data with pandas

# %%
#group product name column
df.groupby('product_name')

# %% [markdown]
# # Aggregating data with Agg()

# %%
#find mean of orders by department
df.groupby('department_id').agg({'order_number':['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1.0              14.792915
# 2.0              17.091743
# 3.0              17.919589
# 4.0              17.891973
# 5.0              15.214270
# 6.0              15.382228
# 7.0              17.699986
# 8.0              16.485269
# 9.0              15.965921
# 10.0             20.091818
# 11.0             16.485395
# 12.0             15.615845
# 13.0             16.485052
# 14.0             17.523474
# 15.0             15.690354
# 16.0             18.014342
# 17.0             16.155822
# 18.0             19.606536
# 19.0             17.630236
# 20.0             17.138204
# 21.0             21.996844

# %%
#alternative way to do this
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1.0     14.792915
# 2.0     17.091743
# 3.0     17.919589
# 4.0     17.891973
# 5.0     15.214270
# 6.0     15.382228
# 7.0     17.699986
# 8.0     16.485269
# 9.0     15.965921
# 10.0    20.091818
# 11.0    16.485395
# 12.0    15.615845
# 13.0    16.485052
# 14.0    17.523474
# 15.0    15.690354
# 16.0    18.014342
# 17.0    16.155822
# 18.0    19.606536
# 19.0    17.630236
# 20.0    17.138204
# 21.0    21.996844
# Name: order_number, dtype: float64

# %%
#multiple aggregations
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1.0              14.792915   1  99
# 2.0              17.091743   1  98
# 3.0              17.919589   1  99
# 4.0              17.891973   1  99
# 5.0              15.214270   1  99
# 6.0              15.382228   1  99
# 7.0              17.699986   1  99
# 8.0              16.485269   1  91
# 9.0              15.965921   1  99
# 10.0             20.091818   1  99
# 11.0             16.485395   1  99
# 12.0             15.615845   1  99
# 13.0             16.485052   1  99
# 14.0             17.523474   1  99
# 15.0             15.690354   1  99
# 16.0             18.014342   1  99
# 17.0             16.155822   1  99
# 18.0             19.606536   1  99
# 19.0             17.630236   1  99
# 20.0             17.138204   1  99
# 21.0             21.996844   1  97

# %% [markdown]
# # Aggregating Data with Transform()

# %%
#run groupby steps
ords_prods_merged['max_order'] = ords_prods_merged.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merged.head(50)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2539329        1    prior             1          2                  8
# 2    2539329        1    prior             1          2                  8
# 3    2539329        1    prior             1          2                  8
# 4    2539329        1    prior             1          2                  8
# 5    2398795        1    prior             2          3                  7
# 6    2398795        1    prior             2          3                  7
# 7    2398795        1    prior             2          3                  7
# 8    2398795        1    prior             2          3                  7
# 9    2398795        1    prior             2          3                  7
# 10   2398795        1    prior             2          3                  7
# 11    473747        1    prior             3          3                 12
# 12    473747        1    prior             3          3                 12
# 13    473747        1    prior             3          3                 12
# 14    473747        1    prior             3          3                 12
# 15    473747        1    prior             3          3                 12
# 16   2254736        1    prior             4          4                  7
# 17   2254736        1    prior             4          4                  7
# 18   2254736        1    prior             4          4                  7
# 19   2254736        1    prior             4          4                  7
# 20   2254736        1    prior             4          4                  7
# 21    431534        1    prior             5          4                 15
# 22    431534        1    prior             5          4                 15
# 23    431534        1    prior             5          4                 15
# 24    431534        1    prior             5          4                 15
# 25    431534        1    prior             5          4                 15
# 26    431534        1    prior             5          4                 15
# 27    431534        1    prior             5          4                 15
# 28    431534        1    prior             5          4                 15
# 29   3367565        1    prior             6          2                  7
# 30   3367565        1    prior             6          2                  7
# 31   3367565        1    prior             6          2                  7
# 32   3367565        1    prior             6          2                  7
# 33    550135        1    prior             7          1                  9
# 34    550135        1    prior             7          1                  9
# 35    550135        1    prior             7          1                  9
# 36    550135        1    prior             7          1                  9
# 37    550135        1    prior             7          1                  9
# 38   3108588        1    prior             8          1                 14
# 39   3108588        1    prior             8          1                 14
# 40   3108588        1    prior             8          1                 14
# 41   3108588        1    prior             8          1                 14
# 42   3108588        1    prior             8          1                 14
# 43   3108588        1    prior             8          1                 14
# 44   2295261        1    prior             9          1                 16
# 45   2295261        1    prior             9          1                 16
# 46   2295261        1    prior             9          1                 16
# 47   2295261        1    prior             9          1                 16
# 48   2295261        1    prior             9          1                 16
# 49   2295261        1    prior             9          1                 16
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      NaN         196                  1          0
# 1                      NaN       14084                  2          0
# 2                      NaN       12427                  3          0
# 3                      NaN       26088                  4          0
# 4                      NaN       26405                  5          0
# 5                     15.0         196                  1          1
# 6                     15.0       10258                  2          0
# 7                     15.0       12427                  3          1
# 8                     15.0       13176                  4          0
# 9                     15.0       26088                  5          1
# 10                    15.0       13032                  6          0
# 11                    21.0         196                  1          1
# 12                    21.0       12427                  2          1
# 13                    21.0       10258                  3          1
# 14                    21.0       25133                  4          0
# 15                    21.0       30450                  5          0
# 16                    29.0         196                  1          1
# 17                    29.0       12427                  2          1
# 18                    29.0       10258                  3          1
# 19                    29.0       25133                  4          1
# 20                    29.0       26405                  5          1
# 21                    28.0         196                  1          1
# 22                    28.0       12427                  2          1
# 23                    28.0       10258                  3          1
# 24                    28.0       25133                  4          1
# 25                    28.0       10326                  5          0
# 26                    28.0       17122                  6          0
# 27                    28.0       41787                  7          0
# 28                    28.0       13176                  8          1
# 29                    19.0         196                  1          1
# 30                    19.0       12427                  2          1
# 31                    19.0       10258                  3          1
# 32                    19.0       25133                  4          1
# 33                    20.0         196                  1          1
# 34                    20.0       10258                  2          1
# 35                    20.0       12427                  3          1
# 36                    20.0       25133                  4          1
# 37                    20.0       13032                  5          1
# 38                    14.0       12427                  1          1
# 39                    14.0         196                  2          1
# 40                    14.0       10258                  3          1
# 41                    14.0       25133                  4          1
# 42                    14.0       46149                  5          0
# 43                    14.0       49235                  6          0
# 44                     0.0       49235                  1          1
# 45                     0.0       46149                  2          1
# 46                     0.0       25133                  3          1
# 47                     0.0         196                  4          1
# 48                     0.0       10258                  5          1
# 49                     0.0       12427                  6          1
#
#                                product_name  aisle_id  department_id  prices  \
# 0                                      Soda      77.0            7.0     9.0
# 1   Organic Unsweetened Vanilla Almond Milk      91.0           16.0    12.5
# 2                       Original Beef Jerky      23.0           19.0     4.4
# 3                Aged White Cheddar Popcorn      23.0           19.0     4.7
# 4          XL Pick-A-Size Paper Towel Rolls      54.0           17.0     1.0
# 5                                      Soda      77.0            7.0     9.0
# 6                                Pistachios     117.0           19.0     3.0
# 7                       Original Beef Jerky      23.0           19.0     4.4
# 8                    Bag of Organic Bananas      24.0            4.0    10.3
# 9                Aged White Cheddar Popcorn      23.0           19.0     4.7
# 10                    Cinnamon Toast Crunch     121.0           14.0     4.0
# 11                                     Soda      77.0            7.0     9.0
# 12                      Original Beef Jerky      23.0           19.0     4.4
# 13                               Pistachios     117.0           19.0     3.0
# 14                    Organic String Cheese      21.0           16.0     8.6
# 15                     Creamy Almond Butter      88.0           13.0     3.2
# 16                                     Soda      77.0            7.0     9.0
# 17                      Original Beef Jerky      23.0           19.0     4.4
# 18                               Pistachios     117.0           19.0     3.0
# 19                    Organic String Cheese      21.0           16.0     8.6
# 20         XL Pick-A-Size Paper Towel Rolls      54.0           17.0     1.0
# 21                                     Soda      77.0            7.0     9.0
# 22                      Original Beef Jerky      23.0           19.0     4.4
# 23                               Pistachios     117.0           19.0     3.0
# 24                    Organic String Cheese      21.0           16.0     8.6
# 25                      Organic Fuji Apples      24.0            4.0     2.7
# 26                        Honeycrisp Apples      24.0            4.0    14.0
# 27                           Bartlett Pears      24.0            4.0     5.0
# 28                   Bag of Organic Bananas      24.0            4.0    10.3
# 29                                     Soda      77.0            7.0     9.0
# 30                      Original Beef Jerky      23.0           19.0     4.4
# 31                               Pistachios     117.0           19.0     3.0
# 32                    Organic String Cheese      21.0           16.0     8.6
# 33                                     Soda      77.0            7.0     9.0
# 34                               Pistachios     117.0           19.0     3.0
# 35                      Original Beef Jerky      23.0           19.0     4.4
# 36                    Organic String Cheese      21.0           16.0     8.6
# 37                    Cinnamon Toast Crunch     121.0           14.0     4.0
# 38                      Original Beef Jerky      23.0           19.0     4.4
# 39                                     Soda      77.0            7.0     9.0
# 40                               Pistachios     117.0           19.0     3.0
# 41                    Organic String Cheese      21.0           16.0     8.6
# 42                        Zero Calorie Cola      77.0            7.0    13.4
# 43                      Organic Half & Half      53.0           16.0     1.8
# 44                      Organic Half & Half      53.0           16.0     1.8
# 45                        Zero Calorie Cola      77.0            7.0    13.4
# 46                    Organic String Cheese      21.0           16.0     8.6
# 47                                     Soda      77.0            7.0     9.0
# 48                               Pistachios     117.0           19.0     3.0
# 49                      Original Beef Jerky      23.0           19.0     4.4
#
#    _merge    price_range_loc     busiest_day busiest_period_of_day  max_order
# 0    both  Mid-Range Product  regularly busy        Average Orders         10
# 1    both  Mid-Range Product  regularly busy        Average Orders         10
# 2    both  Low-Range Product  regularly busy        Average Orders         10
# 3    both  Low-Range Product  regularly busy        Average Orders         10
# 4    both  Low-Range Product  regularly busy        Average Orders         10
# 5    both  Mid-Range Product    slowest days           Most Orders         10
# 6    both  Low-Range Product    slowest days           Most Orders         10
# 7    both  Low-Range Product    slowest days           Most Orders         10
# 8    both  Mid-Range Product    slowest days           Most Orders         10
# 9    both  Low-Range Product    slowest days           Most Orders         10
# 10   both  Low-Range Product    slowest days           Most Orders         10
# 11   both  Mid-Range Product    slowest days           Most Orders         10
# 12   both  Low-Range Product    slowest days           Most Orders         10
# 13   both  Low-Range Product    slowest days           Most Orders         10
# 14   both  Mid-Range Product    slowest days           Most Orders         10
# 15   both  Low-Range Product    slowest days           Most Orders         10
# 16   both  Mid-Range Product    slowest days           Most Orders         10
# 17   both  Low-Range Product    slowest days           Most Orders         10
# 18   both  Low-Range Product    slowest days           Most Orders         10
# 19   both  Mid-Range Product    slowest days           Most Orders         10
# 20   both  Low-Range Product    slowest days           Most Orders         10
# 21   both  Mid-Range Product    slowest days           Most Orders         10
# 22   both  Low-Range Product    slowest days           Most Orders         10
# 23   both  Low-Range Product    slowest days           Most Orders         10
# 24   both  Mid-Range Product    slowest days           Most Orders         10
# 25   both  Low-Range Product    slowest days           Most Orders         10
# 26   both  Mid-Range Product    slowest days           Most Orders         10
# 27   both  Low-Range Product    slowest days           Most Orders         10
# 28   both  Mid-Range Product    slowest days           Most Orders         10
# 29   both  Mid-Range Product  regularly busy           Most Orders         10
# 30   both  Low-Range Product  regularly busy           Most Orders         10
# 31   both  Low-Range Product  regularly busy           Most Orders         10
# 32   both  Mid-Range Product  regularly busy           Most Orders         10
# 33   both  Mid-Range Product    busiest days           Most Orders         10
# 34   both  Low-Range Product    busiest days           Most Orders         10
# 35   both  Low-Range Product    busiest days           Most Orders         10
# 36   both  Mid-Range Product    busiest days           Most Orders         10
# 37   both  Low-Range Product    busiest days           Most Orders         10
# 38   both  Low-Range Product    busiest days           Most Orders         10
# 39   both  Mid-Range Product    busiest days           Most Orders         10
# 40   both  Low-Range Product    busiest days           Most Orders         10
# 41   both  Mid-Range Product    busiest days           Most Orders         10
# 42   both  Mid-Range Product    busiest days           Most Orders         10
# 43   both  Low-Range Product    busiest days           Most Orders         10
# 44   both  Low-Range Product    busiest days           Most Orders         10
# 45   both  Mid-Range Product    busiest days           Most Orders         10
# 46   both  Mid-Range Product    busiest days           Most Orders         10
# 47   both  Mid-Range Product    busiest days           Most Orders         10
# 48   both  Low-Range Product    busiest days           Most Orders         10
# 49   both  Low-Range Product    busiest days           Most Orders         10

# %% [markdown]
# # Deriving Columns with Loc()

# %%
#create column with criteria
ords_prods_merged.loc[ords_prods_merged['max_order'] > 40, 'loyalty_flag'] = 'Loyal Customer'

# %%
ords_prods_merged.loc[(ords_prods_merged['max_order'] <= 40) & (ords_prods_merged['max_order'] > 10), 'loyalty_flag'] = 'Regular Customer'

# %%
ords_prods_merged.loc[ords_prods_merged['max_order'] <= 10, 'loyalty_flag'] = 'New Customer'

# %%
ords_prods_merged['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular Customer    15891507
# Loyal Customer      10294027
# New Customer         6249525
# Name: loyalty_flag, dtype: int64

# %%
#limit view to only essential columns
ords_prods_merged[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New Customer             1
# 1         1      New Customer             1
# 2         1      New Customer             1
# 3         1      New Customer             1
# 4         1      New Customer             1
# 5         1      New Customer             2
# 6         1      New Customer             2
# 7         1      New Customer             2
# 8         1      New Customer             2
# 9         1      New Customer             2
# 10        1      New Customer             2
# 11        1      New Customer             3
# 12        1      New Customer             3
# 13        1      New Customer             3
# 14        1      New Customer             3
# 15        1      New Customer             3
# 16        1      New Customer             4
# 17        1      New Customer             4
# 18        1      New Customer             4
# 19        1      New Customer             4
# 20        1      New Customer             4
# 21        1      New Customer             5
# 22        1      New Customer             5
# 23        1      New Customer             5
# 24        1      New Customer             5
# 25        1      New Customer             5
# 26        1      New Customer             5
# 27        1      New Customer             5
# 28        1      New Customer             5
# 29        1      New Customer             6
# 30        1      New Customer             6
# 31        1      New Customer             6
# 32        1      New Customer             6
# 33        1      New Customer             7
# 34        1      New Customer             7
# 35        1      New Customer             7
# 36        1      New Customer             7
# 37        1      New Customer             7
# 38        1      New Customer             8
# 39        1      New Customer             8
# 40        1      New Customer             8
# 41        1      New Customer             8
# 42        1      New Customer             8
# 43        1      New Customer             8
# 44        1      New Customer             9
# 45        1      New Customer             9
# 46        1      New Customer             9
# 47        1      New Customer             9
# 48        1      New Customer             9
# 49        1      New Customer             9
# 50        1      New Customer            10
# 51        1      New Customer            10
# 52        1      New Customer            10
# 53        1      New Customer            10
# 54        1      New Customer            10
# 55        1      New Customer            10
# 56        1      New Customer            10
# 57        1      New Customer            10
# 58        1      New Customer            10
# 59        2  Regular Customer             1
